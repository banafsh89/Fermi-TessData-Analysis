# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import datetime
from astropy.time import Time
from fermipy.gtanalysis import GTAnalysis
from fermipy.plotting import ROIPlotter
import glob,os,shutil

# %%
#time in config file is in MET
#Setup gta class
#for i in range(1,16):
mysource='4FGL J1806.8+6949'

i=1
print("STARTING {}th Time Bin".format(i))
folderout="dataAll/data{}".format(i)
if not os.path.exists(folderout):
    os.mkdir(folderout) 
    shutil.copyfile("dataAll/events.txt","{}/events.txt".format(folderout))
    shutil.copyfile("dataAll/SC00.fits","{}/SC00.fits".format(folderout))

gta = GTAnalysis('config{}.yaml'.format(i),logging={'verbosity' : 3}) 
gta.setup() #creat all counts map and fits and download all files needed ...

#now lets optimize before doing fit to make sure if we can get rid of sources that are not strong or don't have enough counts
opt1 = gta.optimize()
print("ROI after optimization")
gta.print_roi()

deleted_sources = gta.delete_sources(minmax_ts=[-1,3])
deleted_sources = gta.delete_sources(minmax_npred=[0,1])
print("ROI after deleting the weak sources optimization")
gta.print_roi()

# Free Normalization of all Sources within 3 deg of ROI center
gta.free_sources(distance=3.0,pars='norm')

# Free sources with TS > 10
gta.free_sources(minmax_ts=[10,None],pars='norm')

# Free all parameters of isotropic and galactic diffuse components
gta.free_source('galdiff',pars=['Prefactor'])
gta.free_source('isodiff')

#Free shape parameters of my target
gta.free_source(mysource)#, pars=['Index','Prefactor','Scale'])

fit1 = gta.fit(optimizer='NEWMINUIT',reoptimize=True, max_iter=1000)

print("ROI after fitting")
gta.print_roi()
print(gta.roi[mysource])


#save roi
gta.write_roi('fit1',make_plots=True)

#now creat residual map
fixed_sources = gta.free_sources(free=False)
resid = gta.residmap('3C 371',model={'SpatialModel' : 'PointSource', 'Index' : 2.0})#usually we put the index from the best fit here

o = resid
plt.clf()
fig = plt.figure(figsize=(14,6))
ROIPlotter(o['excess'],roi=gta.roi).plot(vmin=-50,vmax=50,subplot=122,cmap='RdBu_r')
plt.gca().set_title('Excess Counts')
plt.show()

# %matplotlib inline
n, _, _ = plt.hist( resid["sigma"].data.flatten(), bins=np.linspace(-3,3,61), \
                            density=True, histtype="step", label = "Data"  )
def gaussian(x, mu, sig):
    return np.exp(-np.power(x - mu, 2.) / (2 * np.power(sig, 2.)))
x = np.linspace(-3,3, 601)
y = np.exp(-x**2 / 2.0) #gaussian with mean 0 and width 1
norm = n.sum() * 0.1 / (y.sum() * 0.01) #norm factor
plt.plot(x, norm*y, label = "Expectation")
plt.xlabel("Significance")
plt.ylabel("Frequency [a.u.]")
plt.title("Significance distribution")
plt.legend()

#generat TS map
tsmap = gta.tsmap('3C 371',model={'SpatialModel' : 'PointSource', 'Index' : 2.0})

o = tsmap
fig = plt.figure(figsize=(6,6))
ROIPlotter(o['sqrt_ts'],roi=gta.roi).plot(vmin=0,vmax=5,levels=[3,5,7,9],subplot=111,cmap='magma')
plt.gca().set_title('sqrt(TS)')
plt.savefig("{}/resTS.png".format(folderout))
plt.show()

#butterfly plot
source = gta.roi.get_source_by_name(mysource) #model for the source
E = np.array(source['model_flux']['energies'])
dnde = np.array(source['model_flux']['dnde']) #model plot, Central value of spectral band (cm−2 s−1 MeV−1)
dnde_hi = np.array(source['model_flux']['dnde_hi']) #+1 sigma plot upper 1-sigma bound of spectral band (cm−2 s−1 MeV−1)
dnde_lo = np.array(source['model_flux']['dnde_lo']) #-1 sigma plot

ene_arr= gta.log_energies[::3]  ## create SED with a 1/4 of the bins stated in config-file
sed = gta.sed(mysource, make_plots=True,loge_bins=ene_arr)

plt.loglog(E, (E**2)*dnde, 'k--')
plt.loglog(E, (E**2)*dnde_hi, 'k')
plt.loglog(E, (E**2)*dnde_lo, 'k')
plt.errorbar(np.array(sed['e_ctr']),
             sed['e2dnde'], 
             yerr=sed['e2dnde_err'], fmt ='o') #1sigma error on E^2dN/dE evaluated from likelihood curvature.
plt.xlabel('E [MeV]')
plt.ylabel(r'E$^{2}$ dN/dE [MeV cm$^{-2}$ s$^{-1}$]')
plt.savefig("{}/butterfly.png".format(folderout))
plt.show()

#butterfly plot
plt.loglog(E, (E**2)*dnde, 'k--')
plt.loglog(E, (E**2)*dnde_hi, 'k')
plt.loglog(E, (E**2)*dnde_lo, 'k')

TS_thresh=23
measurements=(sed['ts'] >= TS_thresh)
limits = (sed['ts'] < TS_thresh)

plt.errorbar(sed['e_ctr'][measurements],
             sed['e2dnde'][measurements], 
             yerr=sed['e2dnde_err'][measurements], fmt ='o') #1sigma error on E^2dN/dE evaluated from likelihood curvature.
plt.errorbar(np.array(sed['e_ctr'][limits]), 
         sed['e2dnde_ul95'][limits], yerr=0.2*sed['e2dnde_ul95'][limits], 
             fmt='o', uplims=True)
plt.xlabel('E [MeV]')
plt.ylabel(r'E$^{2}$ dN/dE [MeV cm$^{-2}$ s$^{-1}$]')
plt.savefig("{}/butterflyupp.png".format(folderout))
plt.show()

#save average photon flux in energy range that we defined in config file
np.savetxt("{}/flux.txt".format(folderout),[gta.roi.sources[0]._data['flux'],gta.roi.sources[0]._data['flux_err'],gta.roi.sources[0]['ts']], newline=" ")
# Out:
# STARTING 1th Time Bin
# 2023-05-02 14:48:12 INFO    GTAnalysis.__init__():
# --------------------------------------------------------------------------------
# fermipy version 1.2.0
# ScienceTools version 2.2.0
# 2023-05-02 14:48:12 INFO    GTAnalysis.setup(): Running setup.
# 2023-05-02 14:48:12 INFO    GTBinnedAnalysis.setup(): Running setup for component 00
# 2023-05-02 14:48:12 INFO    GTBinnedAnalysis._select_data(): Skipping data selection.
# 2023-05-02 14:48:12 INFO    GTBinnedAnalysis._create_ltcube(): Skipping LT Cube.
# 2023-05-02 14:48:12 INFO    GTBinnedAnalysis._create_expcube(): Skipping gtexpcube.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 '
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATEREF to '2001-01-01T00:01:04.184' from MJDREF.
# Set MJD-OBS to 58682.853102 from DATE-OBS.
# Set MJD-END to 58709.703102 from DATE-END'. [astropy.wcs.wcs]
# 2023-05-02 14:48:12 INFO    GTBinnedAnalysis._create_srcmaps(): Skipping gtsrcmaps.
# 2023-05-02 14:48:12 INFO    GTBinnedAnalysis.setup(): Finished setup for component 00
# 2023-05-02 14:48:12 INFO    GTBinnedAnalysis.setup(): Running setup for component 01
# 2023-05-02 14:48:12 INFO    GTBinnedAnalysis._select_data(): Skipping data selection.
# 2023-05-02 14:48:12 INFO    GTBinnedAnalysis._create_ltcube(): Skipping LT Cube.
# 2023-05-02 14:48:13 INFO    GTBinnedAnalysis._create_expcube(): Skipping gtexpcube.
# 2023-05-02 14:48:13 INFO    GTBinnedAnalysis._create_srcmaps(): Skipping gtsrcmaps.
# 2023-05-02 14:48:13 INFO    GTBinnedAnalysis.setup(): Finished setup for component 01
# 2023-05-02 14:48:13 INFO    GTBinnedAnalysis.setup(): Running setup for component 02
# 2023-05-02 14:48:13 INFO    GTBinnedAnalysis._select_data(): Skipping data selection.
# 2023-05-02 14:48:13 INFO    GTBinnedAnalysis._create_ltcube(): Skipping LT Cube.
# 2023-05-02 14:48:13 INFO    GTBinnedAnalysis._create_expcube(): Skipping gtexpcube.
# 2023-05-02 14:48:13 INFO    GTBinnedAnalysis._create_srcmaps(): Skipping gtsrcmaps.
# 2023-05-02 14:48:13 INFO    GTBinnedAnalysis.setup(): Finished setup for component 02
# 2023-05-02 14:48:13 INFO    GTBinnedAnalysis.setup(): Running setup for component 03
# 2023-05-02 14:48:13 INFO    GTBinnedAnalysis._select_data(): Skipping data selection.
# 2023-05-02 14:48:13 INFO    GTBinnedAnalysis._create_ltcube(): Skipping LT Cube.
# 2023-05-02 14:48:13 INFO    GTBinnedAnalysis._create_expcube(): Skipping gtexpcube.
# 2023-05-02 14:48:13 INFO    GTBinnedAnalysis._create_srcmaps(): Skipping gtsrcmaps.
# 2023-05-02 14:48:13 INFO    GTBinnedAnalysis.setup(): Finished setup for component 03
# 2023-05-02 14:48:13 INFO    GTBinnedAnalysis._create_binned_analysis(): Creating BinnedAnalysis for component 00.
# 2023-05-02 14:48:15 INFO    GTBinnedAnalysis._create_binned_analysis(): Creating BinnedAnalysis for component 01.
# 2023-05-02 14:48:16 INFO    GTBinnedAnalysis._create_binned_analysis(): Creating BinnedAnalysis for component 02.
# 2023-05-02 14:48:17 INFO    GTBinnedAnalysis._create_binned_analysis(): Creating BinnedAnalysis for component 03.
# 2023-05-02 14:48:19 INFO    GTAnalysis.setup(): Initializing source properties
# 2023-05-02 14:48:21 INFO    GTAnalysis.setup(): Finished setup.
# 2023-05-02 14:48:21 INFO    GTAnalysis.optimize(): Starting
# Joint fit  ['galdiff', 'isodiff', '4FGL J1849.2+6705', '4FGL J1748.6+7005', '4FGL J1821.6+6819']
# /Users/banafsheh/mambaforge/envs/fermipy/lib/python3.9/site-packages/scipy/interpolate/_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# Fitting shape 4FGL J1748.6+7005 TS:     94.390
# Fitting shape galdiff TS:     45.834
# 2023-05-02 14:48:44 INFO    GTAnalysis.optimize(): Finished
# 2023-05-02 14:48:44 INFO    GTAnalysis.optimize(): LogLike: -6936.535541 Delta-LogLike: 22.849201
# 2023-05-02 14:48:44 INFO    GTAnalysis.optimize(): Execution time: 22.38 s
# 2023-05-02 14:48:44 INFO    GTAnalysis.print_roi():
# name                SpatialModel   SpectrumType     offset        ts       npred
# --------------------------------------------------------------------------------
# 4FGL J1806.8+6949   PointSource    PowerLaw          0.000      6.28        11.8
# 4FGL J1800.1+7037   PointSource    PowerLaw          0.983     -0.00         0.0
# 4FGL J1757.0+7032   PointSource    LogParabola       1.097       nan         1.0
# 4FGL J1748.6+7005   PointSource    LogParabola       1.583    100.19        43.2
# 4FGL J1823.5+6858   PointSource    LogParabola       1.702      6.26         9.1
# 4FGL J1748.4+7059   PointSource    LogParabola       1.931     -0.00         0.0
# 4FGL J1821.6+6819   PointSource    LogParabola       1.999      5.59        17.0
# 4FGL J1841.6+7113   PointSource    PowerLaw          3.220      0.27         2.0
# 4FGL J1729.3+6931   PointSource    PowerLaw          3.265      1.12         4.3
# 4FGL J1741.1+7226   PointSource    PowerLaw          3.337     -0.00         0.0
# 4FGL J1821.6+6636   PointSource    PowerLaw          3.497      4.49         8.2
# 4FGL J1842.3+6810   PointSource    PowerLaw          3.582      1.00         4.9
# 4FGL J1846.7+7238   PointSource    PowerLaw          4.256     -0.00         0.0
# 4FGL J1758.2+6532   PointSource    PowerLaw          4.364     -0.00         0.0
# 4FGL J1716.1+6836   PointSource    PowerLaw          4.652      0.18         1.9
# 4FGL J1849.2+6705   PointSource    LogParabola       4.750      0.39         3.3
# 4FGL J1853.8+6714   PointSource    PowerLaw          5.002      0.00         0.1
# 4FGL J1807.2+6429   PointSource    PowerLaw          5.328       nan         0.6
# 4FGL J1858.1+7318   PointSource    PowerLaw          5.330      0.66         2.4
# 4FGL J1705.0+7134   PointSource    LogParabola       5.383      1.77         2.2
# 4FGL J1855.4+7350   PointSource    LogParabola       5.497      1.25         6.2
# 4FGL J1848.5+6537   PointSource    PowerLaw          5.748       nan         0.9
# 4FGL J1700.0+6830   PointSource    LogParabola       6.061      0.29         4.1
# 4FGL J1651.6+7219   PointSource    PowerLaw          6.555       nan         0.3
# 4FGL J1842.4+7613   PointSource    PowerLaw          6.881       nan         0.2
# 4FGL J1701.0+6613   PointSource    LogParabola       7.099       nan         0.5
# 4FGL J1646.6+7422   PointSource    PowerLaw          7.595       nan         0.1
# 4FGL J1636.3+7128   PointSource    PowerLaw          7.624       nan         0.1
# 4FGL J1724.9+7654   PointSource    PowerLaw          7.669       nan         0.2
# 4FGL J1637.7+7326   PointSource    PowerLaw          7.827       nan         0.0
# 4FGL J1706.4+6428   PointSource    PowerLaw          7.902       nan         0.0
# 4FGL J1941.7+7218   PointSource    PowerLaw          8.026       nan         0.2
# 4FGL J1704.1+7647   PointSource    LogParabola       8.235       nan         0.3
# 4FGL J1949.2+7250   PointSource    LogParabola       8.651       nan         0.1
# 4FGL J1949.5+7311   PointSource    PowerLaw          8.725       nan         0.1
# 4FGL J1628.2+7518   PointSource    PowerLaw          9.085       nan         0.0
# 4FGL J1910.8+6300   PointSource    LogParabola       9.304       nan         0.0
# 4FGL J1901.0+6208   PointSource    PowerLaw          9.412       nan         0.0
# 4FGL J1619.0+7536   PointSource    LogParabola       9.733       nan         0.0
# isodiff             ConstantValue  FileFunction      -----     16.03       384.6
# galdiff             MapCubeFunctio PowerLaw          -----    475.83       532.8
#
# 2023-05-02 14:48:44 INFO    GTAnalysis.delete_source(): Deleting source 4FGL J1800.1+7037
# 2023-05-02 14:48:44 INFO    GTAnalysis.delete_source(): Deleting source 4FGL J1748.4+7059
# 2023-05-02 14:48:44 INFO    GTAnalysis.delete_source(): Deleting source 4FGL J1841.6+7113
# ROI after optimization
# 2023-05-02 14:48:44 INFO    GTAnalysis.delete_source(): Deleting source 4FGL J1729.3+6931
# 2023-05-02 14:48:44 INFO    GTAnalysis.delete_source(): Deleting source 4FGL J1741.1+7226
# 2023-05-02 14:48:44 INFO    GTAnalysis.delete_source(): Deleting source 4FGL J1842.3+6810
# 2023-05-02 14:48:44 INFO    GTAnalysis.delete_source(): Deleting source 4FGL J1846.7+7238
# 2023-05-02 14:48:44 INFO    GTAnalysis.delete_source(): Deleting source 4FGL J1758.2+6532
# 2023-05-02 14:48:44 INFO    GTAnalysis.delete_source(): Deleting source 4FGL J1716.1+6836
# 2023-05-02 14:48:44 INFO    GTAnalysis.delete_source(): Deleting source 4FGL J1849.2+6705
# 2023-05-02 14:48:45 INFO    GTAnalysis.delete_source(): Deleting source 4FGL J1853.8+6714
# 2023-05-02 14:48:45 INFO    GTAnalysis.delete_source(): Deleting source 4FGL J1858.1+7318
# 2023-05-02 14:48:45 INFO    GTAnalysis.delete_source(): Deleting source 4FGL J1705.0+7134
# 2023-05-02 14:48:45 INFO    GTAnalysis.delete_source(): Deleting source 4FGL J1855.4+7350
# 2023-05-02 14:48:45 INFO    GTAnalysis.delete_source(): Deleting source 4FGL J1700.0+6830
# 2023-05-02 14:48:45 INFO    GTAnalysis.delete_source(): Deleting source 4FGL J1757.0+7032
# 2023-05-02 14:48:45 INFO    GTAnalysis.delete_source(): Deleting source 4FGL J1807.2+6429
# 2023-05-02 14:48:45 INFO    GTAnalysis.delete_source(): Deleting source 4FGL J1848.5+6537
# 2023-05-02 14:48:45 INFO    GTAnalysis.delete_source(): Deleting source 4FGL J1651.6+7219
# 2023-05-02 14:48:45 INFO    GTAnalysis.delete_source(): Deleting source 4FGL J1842.4+7613
# 2023-05-02 14:48:45 INFO    GTAnalysis.delete_source(): Deleting source 4FGL J1701.0+6613
# 2023-05-02 14:48:45 INFO    GTAnalysis.delete_source(): Deleting source 4FGL J1646.6+7422
# 2023-05-02 14:48:45 INFO    GTAnalysis.delete_source(): Deleting source 4FGL J1636.3+7128
# 2023-05-02 14:48:45 INFO    GTAnalysis.delete_source(): Deleting source 4FGL J1724.9+7654
# 2023-05-02 14:48:45 INFO    GTAnalysis.delete_source(): Deleting source 4FGL J1637.7+7326
# 2023-05-02 14:48:45 INFO    GTAnalysis.delete_source(): Deleting source 4FGL J1706.4+6428
# 2023-05-02 14:48:45 INFO    GTAnalysis.delete_source(): Deleting source 4FGL J1941.7+7218
# 2023-05-02 14:48:45 INFO    GTAnalysis.delete_source(): Deleting source 4FGL J1704.1+7647
# 2023-05-02 14:48:45 INFO    GTAnalysis.delete_source(): Deleting source 4FGL J1949.2+7250
# 2023-05-02 14:48:45 INFO    GTAnalysis.delete_source(): Deleting source 4FGL J1949.5+7311
# 2023-05-02 14:48:45 INFO    GTAnalysis.delete_source(): Deleting source 4FGL J1628.2+7518
# 2023-05-02 14:48:45 INFO    GTAnalysis.delete_source(): Deleting source 4FGL J1910.8+6300
# 2023-05-02 14:48:46 INFO    GTAnalysis.delete_source(): Deleting source 4FGL J1901.0+6208
# 2023-05-02 14:48:46 INFO    GTAnalysis.delete_source(): Deleting source 4FGL J1619.0+7536
# 2023-05-02 14:48:46 INFO    GTAnalysis.print_roi():
# name                SpatialModel   SpectrumType     offset        ts       npred
# --------------------------------------------------------------------------------
# 4FGL J1806.8+6949   PointSource    PowerLaw          0.000      6.28        11.8
# 4FGL J1748.6+7005   PointSource    LogParabola       1.583    100.19        43.2
# 4FGL J1823.5+6858   PointSource    LogParabola       1.702      6.26         9.1
# 4FGL J1821.6+6819   PointSource    LogParabola       1.999      5.59        17.0
# 4FGL J1821.6+6636   PointSource    PowerLaw          3.497      4.49         8.2
# isodiff             ConstantValue  FileFunction      -----     16.03       384.6
# galdiff             MapCubeFunctio PowerLaw          -----    475.83       532.8
#
# 2023-05-02 14:48:46 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1748.6+7005     : ['norm']
# 2023-05-02 14:48:46 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1823.5+6858     : ['norm']
# 2023-05-02 14:48:46 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1821.6+6819     : ['norm']
# 2023-05-02 14:48:46 INFO    GTAnalysis.free_source(): Freeing parameters for isodiff               : ['Normalization']
# 2023-05-02 14:48:46 INFO    GTAnalysis.free_source(): Freeing parameters for galdiff               : ['Prefactor']
# 2023-05-02 14:48:46 INFO    GTAnalysis.free_source(): Freeing parameters for galdiff               : ['Index']
# 2023-05-02 14:48:46 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1806.8+6949     : ['Index']
# 2023-05-02 14:48:46 INFO    GTAnalysis.fit(): Starting fit.
# ROI after deleting the weak sources optimization
# 2023-05-02 14:48:51 INFO    GTAnalysis.fit(): Fit returned successfully. Quality:   3 Status:   0
# 2023-05-02 14:48:51 INFO    GTAnalysis.fit(): LogLike:    -6941.276 DeltaLogLike:        1.649
# 2023-05-02 14:48:51 INFO    GTAnalysis.print_roi():
# name                SpatialModel   SpectrumType     offset        ts       npred
# --------------------------------------------------------------------------------
# 4FGL J1806.8+6949   PointSource    PowerLaw          0.000    135.94        18.7
# 4FGL J1748.6+7005   PointSource    LogParabola       1.583    136.70        42.1
# 4FGL J1823.5+6858   PointSource    LogParabola       1.702    133.59         8.2
# 4FGL J1821.6+6819   PointSource    LogParabola       1.999    132.15        14.7
# 4FGL J1821.6+6636   PointSource    PowerLaw          3.497      4.49         8.2
# isodiff             ConstantValue  FileFunction      -----      9.02       419.7
# galdiff             MapCubeFunctio PowerLaw          -----    111.50       532.7
#
# 2023-05-02 14:48:51 INFO    GTBinnedAnalysis.write_xml(): Writing /Users/banafsheh/Desktop/WUSTL2022/jet_var/FermiAnalysis/mywork/Fermipy/dataAll/data1/fit1_00.xml...
# 2023-05-02 14:48:51 INFO    GTBinnedAnalysis.write_xml(): Writing /Users/banafsheh/Desktop/WUSTL2022/jet_var/FermiAnalysis/mywork/Fermipy/dataAll/data1/fit1_01.xml...
# 2023-05-02 14:48:51 INFO    GTBinnedAnalysis.write_xml(): Writing /Users/banafsheh/Desktop/WUSTL2022/jet_var/FermiAnalysis/mywork/Fermipy/dataAll/data1/fit1_02.xml...
# 2023-05-02 14:48:51 INFO    GTBinnedAnalysis.write_xml(): Writing /Users/banafsheh/Desktop/WUSTL2022/jet_var/FermiAnalysis/mywork/Fermipy/dataAll/data1/fit1_03.xml...
# 2023-05-02 14:48:51 INFO    GTAnalysis.write_fits(): Writing /Users/banafsheh/Desktop/WUSTL2022/jet_var/FermiAnalysis/mywork/Fermipy/dataAll/data1/fit1.fits...
# WARNING: Format %s cannot be mapped to the accepted TDISPn keyword values.  Format will not be moved into TDISPn keyword. [astropy.io.fits.column]
# WARNING: Format %f cannot be mapped to the accepted TDISPn keyword values.  Format will not be moved into TDISPn keyword. [astropy.io.fits.column]
# WARNING: Format %s cannot be mapped to the accepted TDISPn keyword values.  Format will not be moved into TDISPn keyword. [astropy.io.fits.column]
# ROI after fitting
# Name           : 4FGL J1806.8+6949
# Associations   : ['4FGL J1806.8+6949', '3C 371']
# RA/DEC         :    271.711/    69.827
# GLON/GLAT      :    100.134/    29.167
# TS             : 135.94
# Npred          : 18.67
# Flux           : 5.368e-09 +/- 2.76e-09
# EnergyFlux     : 3.807e-06 +/-  1.9e-06
# SpatialModel   : PointSource
# SpectrumType   : PowerLaw
# Spectral Parameters
# b'Prefactor'   :  3.104e-12 +/-  1.475e-12
# b'Index'       :     -2.679 +/-     0.5595
# b'Scale'       :        700 +/-        nan
# 2023-05-02 14:48:57 INFO    GTAnalysis.write_roi(): Writing /Users/banafsheh/Desktop/WUSTL2022/jet_var/FermiAnalysis/mywork/Fermipy/dataAll/data1/fit1.npy...
# 2023-05-02 14:48:58 INFO    GTAnalysis.free_source(): Fixing parameters for 4FGL J1806.8+6949     : ['Prefactor', 'Index']
# 2023-05-02 14:48:58 INFO    GTAnalysis.free_source(): Fixing parameters for 4FGL J1748.6+7005     : ['norm']
# 2023-05-02 14:48:58 INFO    GTAnalysis.free_source(): Fixing parameters for 4FGL J1823.5+6858     : ['norm']
# 2023-05-02 14:48:58 INFO    GTAnalysis.free_source(): Fixing parameters for 4FGL J1821.6+6819     : ['norm']
# 2023-05-02 14:48:58 INFO    GTAnalysis.free_source(): Fixing parameters for isodiff               : ['Normalization']
# 2023-05-02 14:48:58 INFO    GTAnalysis.free_source(): Fixing parameters for galdiff               : ['Prefactor', 'Index']
# 2023-05-02 14:48:58 INFO    GTAnalysis.residmap(): Generating residual maps
# 2023-05-02 14:48:58 INFO    GTAnalysis.add_source(): Adding source residmap_testsource
# 2023-05-02 14:49:00 INFO    GTAnalysis.delete_source(): Deleting source residmap_testsource
# 2023-05-02 14:49:00 INFO    GTAnalysis.residmap(): Finished residual maps
# 2023-05-02 14:49:04 WARNING GTAnalysis.residmap(): Saving maps in .npy files is disabled b/c of incompatibilities in python3, remove the maps from the /Users/banafsheh/Desktop/WUSTL2022/jet_var/FermiAnalysis/mywork/Fermipy/dataAll/data1/3C 371_pointsource_powerlaw_2.00_residmap.npy
# 2023-05-02 14:49:04 INFO    GTAnalysis.residmap(): Execution time: 5.45 s
# 2023-05-02 14:49:04 INFO    GTAnalysis.tsmap(): Generating TS map
# 2023-05-02 14:49:05 INFO    GTAnalysis._make_tsmap_fast(): Fitting test source.
# 2023-05-02 14:49:16 INFO    GTAnalysis.tsmap(): Finished TS map
# 2023-05-02 14:49:21 WARNING GTAnalysis.tsmap(): Saving TS maps in .npy files is disabled b/c of incompatibilities in python3, remove the maps from the /Users/banafsheh/Desktop/WUSTL2022/jet_var/FermiAnalysis/mywork/Fermipy/dataAll/data1/3C 371_pointsource_powerlaw_2.00_tsmap.npy
# 2023-05-02 14:49:21 INFO    GTAnalysis.tsmap(): Execution time: 16.43 s
# 2023-05-02 14:49:21 INFO    GTAnalysis.sed(): Computing SED for 4FGL J1806.8+6949
# 2023-05-02 14:49:21 INFO    GTAnalysis._make_sed(): Fitting SED
# 2023-05-02 14:49:21 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1806.8+6949     : ['Prefactor']
# 2023-05-02 14:49:21 INFO    GTAnalysis.sed(): Finished SED
# 2023-05-02 14:49:25 INFO    GTAnalysis.sed(): Execution time: 4.22 s
